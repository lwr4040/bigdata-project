# %%
import sys
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
src= cv2.imread('darpaRobot.bmp')
src2=np.zeros(shape=(512,512),dtype=np.uint8)+255
if src is None:
  print('Image load failed!')
  sys.exit()

# %%
dst=cv2.subtract(src,100)

cv2_imshow(src)
cv2_imshow(dst)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F44CDF79DD0>
# <PIL.Image.Image image mode=RGB size=275x183 at 0x7F44CDF79550>
# -1

# %%
src_gray= cv2.imread('darpaRobot.bmp', cv2.IMREAD_GRAYSCALE)
src2=np.zeros(shape=(512,512),dtype=np.uint8)+255
if src is None:
  print('Image load failed!')
  sys.exit()

# %%
dst_gray=cv2.subtract(src_gray,100)

cv2_imshow(src_gray)
cv2_imshow(dst_gray)
cv2.waitKey()

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=L size=275x183 at 0x7F44CE03F690>
# <PIL.Image.Image image mode=L size=275x183 at 0x7F44CF93A910>

# %%
import cv2
import sys
import numpy as np
from google.colab.patches import cv2_imshow
print(cv2.__version__)
# Out:
# 4.1.2

# %%
img=cv2.imread('/content/drive/MyDrive/kukaRobot..jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=431x460 at 0x7F29EB963110>

# %%
cv2.imwrite('/content/drive/MyDrive/kukaRobotgray..jpg',img)
# Out:
# True

# %%
img2=cv2.imread('/content/drive/MyDrive/kukaRobot..jpg')
img2=cv2.resize(img1,(320,300))
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=320x300 at 0x7F29EB963AD0>

# %%
img3=cv2.imread('/content/drive/MyDrive/kukaRobot..jpg')
img3=cv2.resize(img1,(680,700))
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=680x700 at 0x7F29EB96B490>

# %%
import cv2

img1= cv2.imread('/content/drive/MyDrive/kukaRobotgray..jpg')
height ,width, channel =img1.shape
matrix= cv2.getRotationMatrix2D((width/2, height/2),45,0.5)
dst= cv2.warpAffine(img1, matrix, (width,height))
cv2_imshow(dst)

cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=431x460 at 0x7F29EB96B4D0>

# %%
img4=cv2.flip(img2,0)
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=320x300 at 0x7F29ED1C7250>

# %%
print(cv2_imshow(img1),cv2_imshow(img2),cv2_imshow(img3),cv2_imshow(dst),cv2_imshow(img4),end=" ")
img5=cv2.imread('/content/drive/MyDrive/Screenshot_20220329-130253_Zoom.jpg')
cv2_imshow(img5)
# Out:
# <PIL.Image.Image image mode=RGB size=431x460 at 0x7F29EB888A10>
# <PIL.Image.Image image mode=RGB size=320x300 at 0x7F29EB888610>
# <PIL.Image.Image image mode=RGB size=680x700 at 0x7F29EB888C10>
# <PIL.Image.Image image mode=RGB size=431x460 at 0x7F29EB888150>
# <PIL.Image.Image image mode=RGB size=320x300 at 0x7F29EB888DD0>
# None None None None None
# <PIL.Image.Image image mode=RGB size=493x373 at 0x7F29EB888DD0>

# %%
cv2.imwrite('/content/drive/MyDrive/kukaRobotX..jpg',img1)
cv2.imwrite('/content/drive/MyDrive/kukaRobotY..jpg',img2)
cv2.imwrite('/content/drive/MyDrive/kukaRobotZ..jpg',img3)
cv2.imwrite('/content/drive/MyDrive/kukaRobotA..jpg',img4)
cv2.imwrite('/content/drive/MyDrive/kukaRobotB..jpg',dst)
# Out:
# True
